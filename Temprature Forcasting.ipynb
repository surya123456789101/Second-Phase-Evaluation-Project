# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('temp.csv')

# %%
df.head()
# Out:
#    station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0  30-06-2013          28.7          21.4    58.255688    91.116364
# 1      2.0  30-06-2013          31.9          21.6    52.263397    90.604721
# 2      3.0  30-06-2013          31.6          23.3    48.690479    83.973587
# 3      4.0  30-06-2013          32.0          23.4    58.239788    96.483688
# 4      5.0  30-06-2013          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...  LDAPS_PPT2  \
# 0         28.074101         23.006936  6.818887   69.451805  ...         0.0
# 1         29.850689         24.035009  5.691890   51.937448  ...         0.0
# 2         30.091292         24.565633  6.138224   20.573050  ...         0.0
# 3         29.704629         23.326177  5.650050   65.727144  ...         0.0
# 4         29.113934         23.486480  5.735004  107.965535  ...         0.0
#
# ...

# %%
df.shape
# Out:
# (7752, 25)

# %%
df.isnull().sum()
# Out:
# station              2
# Date                 2
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %%
df.describe()
# Out:
#            station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# count  7750.000000   7682.000000   7682.000000  7677.000000  7677.000000
# mean     13.000000     29.768211     23.225059    56.759372    88.374804
# std       7.211568      2.969999      2.413961    14.668111     7.192004
# min       1.000000     20.000000     11.300000    19.794666    58.936283
# 25%       7.000000     27.800000     21.700000    45.963543    84.222862
# 50%      13.000000     29.900000     23.400000    55.039024    89.793480
# 75%      19.000000     32.000000     24.900000    67.190056    93.743629
# max      25.000000     37.600000     29.900000    98.524734   100.000153
#
#        LDAPS_Tmax_lapse  LDAPS_Tmin_lapse     LDAPS_WS     LDAPS_LH  \
# count       7677.000000       7677.000000  7677.000000  7677.000000
# mean          29.613447         23.512589     7.097875    62.505019
# std            2.947191          2.345347     2.183836    33.730589
# ...

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# station             0
# Date                0
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# dtype: int64

# %%
df.shape
# Out:
# (7588, 25)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7588 entries, 0 to 7749
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7588 non-null   float64
#  1   Date              7588 non-null   object
#  2   Present_Tmax      7588 non-null   float64
#  3   Present_Tmin      7588 non-null   float64
#  4   LDAPS_RHmin       7588 non-null   float64
#  5   LDAPS_RHmax       7588 non-null   float64
#  6   LDAPS_Tmax_lapse  7588 non-null   float64
#  7   LDAPS_Tmin_lapse  7588 non-null   float64
#  8   LDAPS_WS          7588 non-null   float64
#  9   LDAPS_LH          7588 non-null   float64
#  10  LDAPS_CC1         7588 non-null   float64
#  11  LDAPS_CC2         7588 non-null   float64
#  12  LDAPS_CC3         7588 non-null   float64
#  13  LDAPS_CC4         7588 non-null   float64
#  14  LDAPS_PPT1        7588 non-null   float64
#  15  LDAPS_PPT2        7588 non-null   float64
# ...

# %%
df.select_dtypes(include="float64").columns
# Out:
# Index(['station', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin', 'LDAPS_RHmax',
#        'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS', 'LDAPS_LH',
#        'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4', 'LDAPS_PPT1',
#        'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon', 'DEM', 'Slope',
#        'Solar radiation', 'Next_Tmax', 'Next_Tmin'],
#       dtype='object')

# %%
df = df.astype({"station":'str',"Present_Tmax":'str',"Present_Tmin":'str',"LDAPS_RHmin":'str',"LDAPS_RHmax":'str',
               "LDAPS_Tmax_lapse":'str',"LDAPS_Tmin_lapse":'str',"LDAPS_WS":'str',"LDAPS_LH":'str',"LDAPS_CC1":'str',
               "LDAPS_CC2":'str',"LDAPS_CC3":'str',"LDAPS_CC4":'str',"LDAPS_PPT1":'str',"LDAPS_PPT2":'str',"LDAPS_PPT3":'str',
               "LDAPS_PPT4":'str',"lat":'str',"lon":'str',"DEM":'str',"Slope":'str',"Solar radiation":'str',"Next_Tmax":'str',
               "Next_Tmin":'str'})


print(df.dtypes)
# Out:
# station             object
# Date                object
# Present_Tmax        object
# Present_Tmin        object
# LDAPS_RHmin         object
# LDAPS_RHmax         object
# LDAPS_Tmax_lapse    object
# LDAPS_Tmin_lapse    object
# LDAPS_WS            object
# LDAPS_LH            object
# LDAPS_CC1           object
# LDAPS_CC2           object
# LDAPS_CC3           object
# LDAPS_CC4           object
# LDAPS_PPT1          object
# LDAPS_PPT2          object
# LDAPS_PPT3          object
# LDAPS_PPT4          object
# lat                 object
# lon                 object
# DEM                 object
# Slope               object
# Solar radiation     object
# Next_Tmax           object
# Next_Tmin           object
# dtype: object

# %%
from sklearn.preprocessing import OrdinalEncoder

enc = OrdinalEncoder()


df['Date'] = enc.fit_transform(df['Date'].values.reshape(-1,1))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7588 entries, 0 to 7749
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7588 non-null   object
#  1   Date              7588 non-null   float64
#  2   Present_Tmax      7588 non-null   object
#  3   Present_Tmin      7588 non-null   object
#  4   LDAPS_RHmin       7588 non-null   object
#  5   LDAPS_RHmax       7588 non-null   object
#  6   LDAPS_Tmax_lapse  7588 non-null   object
#  7   LDAPS_Tmin_lapse  7588 non-null   object
#  8   LDAPS_WS          7588 non-null   object
#  9   LDAPS_LH          7588 non-null   object
#  10  LDAPS_CC1         7588 non-null   object
#  11  LDAPS_CC2         7588 non-null   object
#  12  LDAPS_CC3         7588 non-null   object
#  13  LDAPS_CC4         7588 non-null   object
#  14  LDAPS_PPT1        7588 non-null   object
#  15  LDAPS_PPT2        7588 non-null   object
# ...

# %%
X = df.drop(columns=['Next_Tmax','Next_Tmin'],axis=1)
Y = df['Next_Tmin']

# %%
print(X)
print(Y)
# Out:
#      station   Date Present_Tmax Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0        1.0  288.0         28.7         21.4  58.25568771  91.11636353
# 1        2.0  288.0         31.9         21.6  52.26339722  90.60472107
# 2        3.0  288.0         31.6         23.3  48.69047928  83.97358704
# 3        4.0  288.0         32.0         23.4  58.23978806  96.48368835
# 4        5.0  288.0         31.4         21.9  56.17409515  90.15512848
# ...      ...    ...          ...          ...          ...          ...
# 7745    21.0  302.0         23.1         17.8  24.68899727  78.26138306
# 7746    22.0  302.0         22.5         17.4  30.09485817   83.6900177
# 7747    23.0  302.0         23.3         17.1  26.74131012  78.86985779
# 7748    24.0  302.0         23.3         17.7  24.04063416  77.29497528
# 7749    25.0  302.0         23.2         17.4  22.93301392   77.2437439
#
#      LDAPS_Tmax_lapse LDAPS_Tmin_lapse     LDAPS_WS     LDAPS_LH  ...  \
# ...

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state=2)

# %%
print(Y.shape, Y_train.shape, Y_test.shape)
# Out:
# (7588,) (6070,) (1518,)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (7588, 23) (6070, 23) (1518, 23)

# %%
from sklearn import svm

# %%
model = svm.SVC(kernel='linear')

# %%
model.fit(X_train, Y_train)
# Out:
# SVC(kernel='linear')

# %%
X_train_prediction = model.predict(X_train)

data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy:', data_accuracy)
# Out:
# Accuracy: 0.14546952224052717
